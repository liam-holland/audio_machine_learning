# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import librosa
from glob import glob
from torch.utils.data import Dataset, DataLoader
import sklearn.metrics

# %% [markdown]
# # Python Libraries
#
# You do not need to use any Python libraries in addition to those listed above. Do not import any other libraries. If you think I have missed out a library that you are meant to use during this assignment, please contact me.

# %% [markdown]
# # Audio Machine Learning - Summative Assessment 1 - Machine Learning Challenge - Part 2

# %% [markdown]
# For the second part of the machine learning challenge, your task is to implement and train a spoken digit classifier using PyTorch
#
# The model is intended to classify spoken digits, specifically the numbers 0 to 9 spoken in English.

# %% [markdown]
# There are sections in the Notebook which are left for you to complete, which will be assessed. This will be marked as below:

# %% [markdown]
# This will be marked as below:
#
# ## __Assessed Section__
# ----------

# %%
# Any code cells in the 'Assessed Section' are part of the assessment. 
# There will be instructions for you to follow within these parts of the notebook.
# Your submission will be the Notebook file, with the Assessed Sections filled in
# This one doesn't count, as it is just a demonstration!

# %% [markdown]
# ----------
# ## __End of Assessed Section__

# %% [markdown]
# ***
# ***
#
# # Downloading the Dataset
#
# The dataset for this assignment is available to download from GitHub at the following URL:
#
# https://github.com/Alec-Wright/Digits
#
#
# ### Downloading in Noteable
# You can download this directly into Noteable by:
#
# - Opening Noteable
# - Clicking the 'Git' menu item at the top of the window
# - Selecting 'Clone a Repository'
# - Entering the url 'https://github.com/Alec-Wright/Digits'
# - Clicking Clone
#
# More information available here if you have trouble.
#
# https://noteable.edina.ac.uk/user-guide/#up_4
#
# ### Downloading to Computer
# - Go to https://github.com/Alec-Wright/Digits
# - Click the green '<> code' button
# - Click 'Download ZIP'
# - Unzip the downloaded .zip file
#
# This should download a folder called 'Digits', within which are various subfolers containing '.wav' files of human speech.
#
# Please contact me if you are unable to download the dataset.

# %% [markdown]
# ***
# ***
# ## **Task 1** - Dataset Exploration

# %% [markdown]
# In the folder 'Digits', there is a folder called 'Data' that holds recordings of spoken digits, from various speakers, speaking the digits 0 to 9. This is from the 'Audio MNIST' dataset.
#
# Each audio file in the dataset is a '.wav' file that contains a recording of one speaker saying one of the digits.
#
# The folders are organised by speaker, so 'Data/01/' contains digits spoken by speaker '01' and 'Data/02/' contains digits spoken by speaker '02', and so on.

# %% [markdown]
# ## __Assessed Section - 2.1__
# ----------
#
# Your task is to:
# - Determine how many audio files are in the dataset held in 'Digits/Data/' (including all subfolders). Save this to a variable called 'dataset_size'.
# - Use Librosa to load each file and find its length in samples. Determine the length of the longest audio file, and the shortest audio file, in samples. Save these to variables called 'longest_length' and 'shortest_length'.
# - For each of the 10 digits, count how many examples are contained in the dataset. Save this as a list to a variable called 'class_counts'

# %%
# Your solution here

# Get a list of all files
file_list =  np.array( glob( "**/*.wav", root_dir="./Data" , recursive=True ))

# Size of the dataset
dataset_size = len(file_list)

# Create a dictonary of the dataset
folder = np.reshape( np.array([substring[0:2] for substring in file_list]),(-1,1)  )
file = np.reshape(file_list,(-1,1))
number =  np.reshape( np.array([substring[3:4] for substring in file_list]),(-1,1) )
speaker = np.reshape( np.array([substring[5:7] for substring in file_list]),(-1,1) )
recording_id = np.reshape( np.array( [substring[8:-4] for substring in file_list]),(-1,1) )

file_dict = {
    "folder" : folder,
    "file" : file,
    "number" : number,
    "speaker": speaker,
    "recording_id" : recording_id
}

# %%
# Add the duration of the files in samples to the dataset
duration = np.zeros((dataset_size,1))

for i, f in enumerate(file_list):
    duration[i,:] = len(librosa.load( f"./Data/{f}", sr=None)[0])

file_dict["duration"] = duration

# %%
# Find the longest sample. shortest and the number of times each number is spoken

longest_length = np.max(duration, axis=0)
shortest_length = np.min(duration, axis=0)

number_counts_tup = np.unique(number, return_counts=True)
class_counts = np.array(number_counts_tup)[1][:]

# %% [markdown]
# ----------
# ## __End of Assessed Section - 2.1__

# %% [markdown]
# ***
# ***
# ## **Task 2** - Zero Padding and Preprocessing

# %% [markdown]
# Each audio file is of a different length. We want them all to be the same length, for processing in batches with our neural network. We can do this by adding zeros to the end of shorter files, or by truncating longer files (cutting the end off).
#
# We then want to create a time-frequency representation of the audio, which we will extract using Librosa.
#
# Write a function, 'adjust_length', that adjusts the length of some input audio data. It should have the following arguments:
# - audio_data: a numpy array of shape $(t,)$, where $t$ is the length of the audio in samples
# - target_length: an Integer that describes the target length in samples of the audio
#
# The function should:
# - Either apply zero-padding or truncate the audio data such that it is of shape (target_length,)
# - The function should then return the input audio, which is now of the shape  (target_length,)
#
#
# Write another function, 'preprocess', that normalises some input audio data, and then creates a time-frequency representation of it. It should take the following arguments:
# - audio_data: a numpy array of shape $(t,)$, where $t$ is the length of the audio in samples
# - sample_rate: An integer that represents the sample rate of audio_data
#
# The function should:
# - Normalise the audio data. Multiply it by some scalar such that np.max(np.abs(audio_data)) = 1.
# - Extract the mel spectrogram of the audio_data using Librosa. Use the librosa.feature.melspectrogram() function, ensuring to provide the correct sample rate to the function. You can use the default parameters for melspectrogram().
# - Return the extracted mel-spectrogram

# %% [markdown]
# ## __Assessed Section - 2.2__
# ----------
#
# Your task is to:
# - Implement the two functions described above, in the templates below:

# %%
def adjust_length(audio_data, target_length):
    ## Implement the function here

    audio_length = np.shape(audio_data)[0]
    
    diff = target_length - audio_length

    # Need to padd if shorted and cut if too long
    if (diff > 0):
        padded_audio = np.pad(array=audio_data, pad_width = (0,diff) , mode = 'constant' , constant_values = 0)
    else:
        padded_audio = audio_data[0:target_length ]

    return padded_audio

def preprocess(audio_data, sample_rate):
    ## Implement the function here
    
    normalised_audio = audio_data / np.max(np.abs(audio_data))

    assert ( np.max(np.abs(normalised_audio)) == 1 ) , "Values exceed +- 1"

    spectrogram = librosa.feature.melspectrogram( sr=sample_rate , y=normalised_audio)
    
    return spectrogram

# %%
# Test the function
audio_data = librosa.load(path=r"./Data/01/0_01_0.wav")[0]
a = adjust_length(audio_data=audio_data , target_length= 20000)
b = preprocess(audio_data=a , sample_rate= 22050) 

del audio_data ,a ,b

# %% [markdown]
# ----------
# ## __End of Assessed Section - 2.2__

# %% [markdown]
# ***
# ***
# ## **Task 3** - Creating the Datasets

# %% [markdown]
# We will create a dataset using the recordings from speaker '01'. The audio from speaker 01 is contained in the folder 'Data/01/'
#
# Each audio file is named in the following format:
#
# 'digit_speaker_i.wav'
#
# What appears before the first underscore is the digit being spoken.
# What appears after the first underscore is the speaker identity.
# What appears after the second underscore is the index.
#
# So:
#
#     '0_01_0.wav'
#
# is the digit '0'\
# spoken by speaker '01'\
# and it is the first recording of speaker '01' saying '0' in the dataset.
#
#     '0_01_1.wav'
#
# is the digit '0'\
# spoken by speaker '01'\
# and it is the SECOND recording of speaker '01' saying '0' in the dataset.
#
# and so on.
#
#
# The dataset will be split into three subsets. For each digit, the first 40 examples of that digit should be placed in the _training_ dataset. The next 5 examples should be placed in the _validation_ dataset, and the final 5 should be placed in the _test_ dataset.

# %% [markdown]
# ## __Assessed Section - 2.3__
# ----------
#
# Your task is to:
# - Create the three data subsets as described above
# - Create a list of the filenames of the audio to be contained in each subset
# - For each file:
#     - Load the audio using Librosa, resampling to a sample_rate of 22050
#     - Use the adjust_length function you defined earlier to adjust the length of the audio data to exactly 1-second
#     - Use the preprocess function you defined earlier to extract the time-frequency representation
#     - Determine the label of the file from the filename (using the filename.split('_') method might be useful here)
# - For each subset:
#     - Extract the time-frequency representation of all the audio files contained in that subset, as well as the labels
#     - Create a PyTorch tensor that holds all the time-frequency representations of the data in that subset. Ensure it is of datatype 'float32'. It should be a tensor of shape (N, C, T), where N is the number of datapoints in that subset, C is the number of frequency bins in the mel-spectrogram, and T is the length of the mel-spectrogram in frames.
#     - Create a PyTorch tensor that holds the labels corresponding to each of the N examples held in the tensor of features. It should be of shape (N,)
#
# Save the features to the variables:
#     'train_features', 'val_features' and 'test_features'
#
# Save the labels to the variables:
#     'train_labels', 'val_labels', 'test_labels'

# %% [markdown]
# ALL THE SPEAKERS - Use this code if want to test all the speakers and not only one

# %%
# Your solution here

# unique_speakers = np.unique( speaker )
# include_speakers_start = 0
# include_speaker_end = 20
# unique_speakers_sliced = unique_speakers[include_speakers_start:include_speaker_end]

# speaker_dict = {}
# for sp in unique_speakers_sliced:
#     folder = f"./Data/{sp}"
#     files = np.array(sorted(glob(f"{folder}/*.wav")))
#     speaker_dict[folder] = files

# train_files = []
# test_files = []
# val_files = []


# for folder, files in speaker_dict.items():

#     for digit in range(10):

#         start = digit * 50
#         end = start + 50
#         digit_files = files[start:end]

#         train_files.extend(digit_files[:40])
#         test_files.extend(digit_files[40:45])
#         val_files.extend(digit_files[45:])

# %% [markdown]
# ONLY SPEAKER 1

# %%
speaker_folder = "./Data/01"
 
# Sort the files and create an array
files = np.array(sorted(glob(f"{speaker_folder}/*.wav")))

# Create empty lists to fill
train_files = []
test_files = []
val_files = []

# Since speaker '01' has 50 recordings for each of the 10 digits:
for digit in range(10):

    # Each digit has a block of 50 files
    start = digit * 50
    end = start + 50
    digit_files = files[start:end]

    # Split: 40 train, 5 val, 5 test
    train_files.extend(digit_files[:40])
    test_files.extend(digit_files[40:45])
    val_files.extend(digit_files[45:])

print(f"Training files: {len(train_files)}")  # Should be 400
print(f"Validation files: {len(val_files)}")  # Should be 50
print(f"Test files: {len(test_files)}")       # Should be 50
# Out:
# Training files: 400
# Validation files: 50
# Test files: 50

# %%
def file_process( file ):
    sample_rate = 22050
    desired_length = 1

    # librosa.load returns a tuple: (y, sr)
    resample, _sampleRate = librosa.load(file, sr=sample_rate)

    adjusted_length = adjust_length(resample, int(desired_length * sample_rate))
    frequency_info = preprocess(adjusted_length, sample_rate)

    # extract digit label from filename
    file = file.replace("\\", "/")
    file_name = file.split("/")[-1]       
    digit_label = int(file_name[0])     

    return frequency_info, digit_label

def features_and_labels( files ):

    _features = []
    _labels = []

    # Loop through the files and process them
    for file in files:
        feature, label = file_process(file)
        _features.append(feature)
        _labels.append(label)

    _features = np.array(_features)
    _labels = np.array(_labels)

    # Create feature and label tensors
    _features = torch.from_numpy(_features).type(torch.float32)
    _labels = torch.from_numpy(_labels).type(torch.long)

    return _features, _labels

# %%
train_features , train_labels = features_and_labels(train_files)
test_features , test_labels = features_and_labels(test_files)
val_features , val_labels = features_and_labels(val_files)

# %% [markdown]
# ----------
# ## __End of Assessed Section - 2.3__

# %% [markdown]
# ***
# ***
# ## **Task 4** - Datasets and DataLoaders
#
# We will now create the Dataset class, which will hold our extracted features and labels

# %% [markdown]
# ## __Assessed Section - 2.4__
# ----------
#
# Create an AudioDataSet class, using the template below:
# - It should take PyTorch tenors holding features and corresponding labels of a dataset as its constructor arguments
# - It should save these as attributes in the constructor
# - The \_\_getitem\_\_ method should take the integer 'i' as its argument, and return both the features and corresponding label for the $i-th$ item from the dataset
# - The \_\_len\_\_ method should return an integer, that is equal to the number of data points held in the dataset

# %%
class AudioDataSet(Dataset):              # Don't change this line
    def __init__(self, features, labels): # Don't change this line

        # Error messages recommended that I detach and clone
        self.features = features.detach().clone().to(torch.float32)
        self.labels = labels.detach().clone().to(torch.long)
        
    def __getitem__(self, i):             # Don't change this line
        feature = self.features[i]
        label = self.labels[i]  

        return feature, label
 
    def __len__(self):                    # Don't change this line
        return len(self.labels)

# %% [markdown]
# ----------
# ## __End of Assessed Section - 2.4__

# %% [markdown]
# ***
# ***
# # __Task 5__ - Neural Network Creation
#
# We want to make a multi-class classifier, that takes in the time-frequency representation of the audio as input, and predicts the digit that is being spoken.
#
# We will do this using a convolutional neural network.
#
# First, define a Convolutional Block Class. The Convolutional block will consist of a 1D-Convolutional layer, followed by a ReLU activation function. The convolutional block should process inputs through these two layers, and then return the output.  The number of input channels, output channels, and kernel size should be determined by arguments provided to the class constructor. The convolutional block should __not__ apply any zero-padding.
#
# Then, define a Convolutional Neural Network (CNN) Class. It should consist of 8 of the Convolutional blocks defined previously. It should process inputs sequentially through each of the eight blocks.
#
# After the eighth block, the network should apply global average pooling, which should apply pooling in the time-dimension only, reducing the output to a single value in the time-dimension, but not applying averaging over the channel or batch dimensions. Finally, a linear layer should be applied, converting the final output to a tensor with the appropriate shape for this multi-class classification problem.

# %% [markdown]
# ## __Assessed Section - 2.5__
# ----------
#
# Your task it to:
# - Create the ConvBlock class described above, using the template provided
# - Create the ConvNet class described above, using the template provided
# - Create an instance of your ConvNet class, with kernel size of 5. The number of input channels for the first convolutional block should be chosen based on the dimensionality of the time-frequency representation of your data. Otherwise, the number of channels for convolutional layers should be 16.
# - Process some data through the neural network class, and compare the shapes of the input and output Tensors. You may use data extracted earlier, or you may create random data using torch.randn(N,C,T), where N is the batch size, C is the channel dimensions and T is the number of frames in the time-frequency representation.

# %%
## I have added in activation for the further work

class ConvBlock(torch.nn.Module):                       # Don't change this line
    def __init__(self, _inChannels, _outChannels, _kernelSize, _activation):                 # Add arguments to the constructor method of your Class
        super(ConvBlock, self).__init__()               # Don't change this line
        self.conv = torch.nn.Conv1d(in_channels=_inChannels , out_channels=_outChannels, padding=0, kernel_size = _kernelSize)
        self.act = _activation

    def forward(self, x):                               # Don't change this line
        # Define forward method here
        z1 = self.conv(x)
        a1 = self.act(z1)
        return a1

# %% [markdown]
# **Further work** - Adjust your ConvNet class, so it can receive arguments determining the number of blocks and the activation function used.

# %%
class ConvNet(torch.nn.Module):                         # Don't change this line
    def __init__(self, _inChannels, _outChannels, _kernelSize, _numClasses, _numBlocks, _activation):    # Add arguments to the constructor method of your Class
        super(ConvNet, self).__init__()                 # Don't change this line
        self.in_channels = _inChannels
        self.out_channels = _outChannels
        self.kernel_size = _kernelSize


        module_list = []

        # Create a given number of process blocks
        for b in range(_numBlocks):
            if b == 0:
                module_list.append(ConvBlock(_inChannels, _outChannels, _kernelSize, _activation))
            else:
                module_list.append(ConvBlock(_outChannels, _outChannels, _kernelSize, _activation))

        self.blocks = torch.nn.ModuleList(module_list)

        # The last layer will give us the number of final classes
        self.linear = torch.nn.Linear(_outChannels, _numClasses)

    def forward(self, x):

        for block in self.blocks:
            x = block(x)

        x = x.mean(dim=2)      
        x = self.linear(x)     
        
        return x

# %%
# Create an instance of your network, as process some input with it as described above.
frequency_time_size = torch.Tensor.size(test_features)[1]
model = ConvNet(frequency_time_size, 16, 5, 10, _numBlocks=8 ,_activation=torch.nn.ReLU())

# Do one forward pass. Compare the shape of the input and output
train_output = model.forward(train_features)

print(f"The tensor input has dimensions {tuple(train_features.shape)}")
print(f"The tensor output has dimensions {tuple(train_output.shape)}")
# Out:
# The tensor input has dimensions (400, 128, 44)
# The tensor output has dimensions (400, 10)

# %% [markdown]
# ----------
# ## __End of Assessed Section - 2.5__

# %% [markdown]
# ***
# ***
# ## Task 6 - Neural Network Training
#
# Now you will train your Neural Network Digit Classifier.
#
# The Training Loop. One iteration of the Training Loop should carry out Stochastic Gradient Descent over the full training dataset, in random batches of batch size 50. Iterating over the complete training dataset once is commonly known as 'one training epoch'. You may use the PyTorch DataLoader class when creating the training loop. Each training epoch must use every item in the training dataset exactly once.
# Use the Adam optimiser, with default settings, available as 'torch.optim.Adam()'. Ensure you pass the model parameters to the optimiser.
# Use the Cross-Entropy Loss function. You may use the PyTorch cross-entropy loss function class.
# After each training epoch, save the average loss over the full training subset to a list of losses.
#
# The Validation Loop. The Validation Loop should calculate the average loss and accuracy of the model over the whole Validation subset. The validation loss should be saved to a list of validation losses and the validation accuracy should be saved to a list of validation accuracies.
#
# The Test Loop. The Test Loop should calculate the average loss and accuracy of the model over the whole test subset. The test loop should also calculate the accuracy for each class, and generate a confusion matrix. You may you sklearn.metrics to create the confusion matrix.

# %% [markdown]
# ## __Assessed Section - 2.6__
# ----------
#
# Your task it to:
# - Create the Training, Validation and Test loops described above.
# - Train your neural network for 100 epochs, calculating the validation loss and accuracy every 5th epoch.
# - After training is complete, run the test loop. Display the confusion matrix, and save the resulting figure to a file called 'DigitClassifierConfusion.png'. Include this file with your submission.

# %%
# Create our datasets

train_ds = AudioDataSet(train_features, train_labels)
test_ds = AudioDataSet(test_features, test_labels)
val_ds = AudioDataSet(val_features, val_labels)

# %%
# Randomly shuffle the data with a batch size of 50

batch_size = 50

train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False) # No need to shuffle validation/test sets
test_loader  = DataLoader(test_ds,  batch_size=batch_size, shuffle=False) # No need to shuffle validation/test sets

# %%
#Code for one epoch
def train_one_epoch(dataloader, model, loss_fn, optimiser):

    running_loss = 0.0
    correct = 0
    total = 0

    # For-loop that iterates over each batch in the dataloader
    for X, y in dataloader:

        # Zero grad
        optimiser.zero_grad()

        # Forward Pass
        y_hat = model(X)

        # The loss function expects a long format
        y = y.long()

        # Calculate Loss - expects (input, target)
        loss = loss_fn( y_hat , y )

        # Backward Pass
        loss.backward()

        # Update Parameters
        optimiser.step()

        # Log training stats
        running_loss += loss.item() 
        predicted_class = torch.argmax(y_hat, dim=1)
        correct += (predicted_class == y).sum().item()
        total += X.size(0)

    # Divide running loss by number of batches
    avg_loss = running_loss / len(dataloader)

    # Find accuracy over full dataset

    acc = correct / total
    return avg_loss, acc

# %%
# Evaluate the model

def evaluate(dataloader, model, loss_fn):
    running_loss = 0.0
    correct = 0
    total = 0

    for X, y in dataloader:

        y_hat = model(X)

        y = y.long()
        loss = loss_fn( y_hat , y)

        # Log evaluation stats
        running_loss += loss.item()
        predicted_class = torch.argmax(y_hat, dim=1) 
        correct += (predicted_class == y).sum().item()
        total += X.size(0)

    # Divide running loss by number of batches
    avg_loss = running_loss / len(dataloader)
    # Find accuracy over full dataset
    acc = correct / total
    return avg_loss, acc

# %%
# Re-intialise the model

model = ConvNet( _inChannels= frequency_time_size, _outChannels= 16, _kernelSize= 5, _numClasses=10 , _numBlocks=8 ,_activation=torch.nn.ReLU())
learning_rate = 0.001
optimiser = torch.optim.Adam(params=model.parameters())
loss_fn = torch.nn.CrossEntropyLoss()

# %%
# Define number of training epochs
epochs = 100

# Lists for monitoring training
train_loss_list, train_acc_list = [], []
val_loss_list, val_acc_list = [], []

# Loop for neural network training
for epoch in range(1, epochs + 1):
    
    train_loss, train_acc = train_one_epoch(train_loader, model, loss_fn, optimiser)

    if epoch % 5 == 0:

        # This disables gradient tracking in torch for the indented code
        # It isn't strictly neccessary but saves computational cost
        with torch.inference_mode():
            val_loss, val_acc = evaluate(val_loader, model, loss_fn)

        train_loss_list.append(train_loss)
        train_acc_list.append(train_acc)
        val_loss_list.append(val_loss)
        val_acc_list.append(val_acc)

        print(
            f"Epoch {epoch:02d} | "
            f"train loss {train_loss:.4f}, train acc {train_acc:.3f} | "
            f"val loss {val_loss:.4f}, val acc {val_acc:.3f}"
        )
# Out:
# Epoch 05 | train loss 1.8339, train acc 0.318 | val loss 1.7126, val acc 0.300
# Epoch 10 | train loss 0.9766, train acc 0.655 | val loss 0.8279, val acc 0.720
# Epoch 15 | train loss 0.3646, train acc 0.892 | val loss 0.3993, val acc 0.880
# Epoch 20 | train loss 0.2268, train acc 0.943 | val loss 0.2949, val acc 0.860
# Epoch 25 | train loss 0.0779, train acc 0.983 | val loss 0.1733, val acc 0.960
# Epoch 30 | train loss 0.1885, train acc 0.968 | val loss 0.3868, val acc 0.880
# Epoch 35 | train loss 0.0384, train acc 0.998 | val loss 0.1301, val acc 0.960
# Epoch 40 | train loss 0.0108, train acc 0.998 | val loss 0.1261, val acc 0.960
# Epoch 45 | train loss 0.0223, train acc 0.990 | val loss 0.2082, val acc 0.900
# Epoch 50 | train loss 0.0034, train acc 1.000 | val loss 0.1085, val acc 0.980
# Epoch 55 | train loss 0.0019, train acc 1.000 | val loss 0.1142, val acc 0.980
# Epoch 60 | train loss 0.0012, train acc 1.000 | val loss 0.1202, val acc 0.980
# Epoch 65 | train loss 0.0009, train acc 1.000 | val loss 0.1237, val acc 0.980
# Epoch 70 | train loss 0.0007, train acc 1.000 | val loss 0.1267, val acc 0.980
# Epoch 75 | train loss 0.0006, train acc 1.000 | val loss 0.1276, val acc 0.980
# Epoch 80 | train loss 0.0005, train acc 1.000 | val loss 0.1320, val acc 0.980
# Epoch 85 | train loss 0.0004, train acc 1.000 | val loss 0.1332, val acc 0.980
# Epoch 90 | train loss 0.0003, train acc 1.000 | val loss 0.1359, val acc 0.980
# Epoch 95 | train loss 0.0003, train acc 1.000 | val loss 0.1371, val acc 0.980
# Epoch 100 | train loss 0.0003, train acc 1.000 | val loss 0.1382, val acc 0.980

# %%
# This creates a range: 5,10,5 ...
plot_epochs = range(5, (len(train_loss_list) * 5) + 1, 5)

# Plot the train and validation results over epochs
plt.subplot(1, 2, 1)
plt.plot(plot_epochs, train_loss_list, label="train")
plt.plot(plot_epochs, val_loss_list, label="validation")
plt.title("Loss")
plt.xlabel("Epoch")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(plot_epochs, train_acc_list, label="train")
plt.plot(plot_epochs, val_acc_list, label="validation")
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

unique_numbers_int = np.unique(number).astype(int)

def predict_labels(dataloader, model):
    all_preds = []
    all_true = []

    # Iterate over dataset
    for X, y in dataloader:

        # Get model predicitions
        y_hat = model(X)
        predicted_class = torch.argmax(y_hat, dim=1) 

        # Save model predicted classes and corresponding labels
        all_preds.append(predicted_class)
        all_true.append(y.numpy().astype(int))

    return np.concatenate(all_true), np.concatenate(all_preds)

with torch.inference_mode():
    y_true, y_pred = predict_labels(test_loader, model)
    
# Create confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=unique_numbers_int)

# Plot and save as .png
disp = sklearn.metrics.ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(number))
print("\nReport:\n", classification_report(y_true, y_pred, target_names=np.unique(number)))
disp.plot()
plt.title("Confustion Matrix - Speaker 1 only")
plt.savefig("DigitClassifierConfusion.png")
# Out:
# Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      0.80      0.89         5
#            2       1.00      0.80      0.89         5
#            3       0.83      1.00      0.91         5
#            4       1.00      1.00      1.00         5
#            5       0.80      0.80      0.80         5
#            6       1.00      1.00      1.00         5
#            7       0.80      0.80      0.80         5
#            8       1.00      1.00      1.00         5
#            9       0.83      1.00      0.91         5
#
#     accuracy                           0.92        50
#    macro avg       0.93      0.92      0.92        50
# weighted avg       0.93      0.92      0.92        50

# %% [markdown]
# ----------
# ## __End of Assessed Section - 2.6__

# %% [markdown]
# ***
# ***
# # __Further Work__
#
# The above is sufficient to achieve a mark of 60 for Postgraduate students and 67 for Undergraduate Students. if you wish to go further to get a higher grade, you can try and implement some of the following:
#
# - Does the trained classifier generalise to other speakers? Test this using other data from the dataset provided.
# - Try increasing the diversity of the data used during training, by including more speakers. Train a model using this dataset, and test if this model generalises better to speakers that weren't included in the training set.
# - Adjust your ConvNet class, so it can receive arguments determining the number of blocks and the activation function used.
# - There are many choices you could make to change the neural network architecture, or the training process generally. For example, adjusting the number of blocks, changing the time-frequency representation used or adjusting the number of channels in the convolutional layers. Pick one or two of these and run experiments to compare how making changes to these influences the performance of the trained neural network model. Write in a markdown cell a summary of your findings and any conclusions you can draw about the adjustments you made.

# %% [markdown]
# **TESTING ON OTHER SPEAKERS**

# %%
# Want to create data from the rest of the speakers
unique_speakers = np.unique( speaker )
include_speakers_start = 1
include_speaker_end = 20
unique_speakers_sliced = unique_speakers[include_speakers_start:include_speaker_end]

speaker_dict = {}
for sp in unique_speakers_sliced:
    folder = f"./Data/{sp}"
    files = np.array(sorted(glob(f"{folder}/*.wav")))
    speaker_dict[folder] = files

test_files_other = []

for folder, files in speaker_dict.items():

    for digit in range(10):

        start = digit * 50
        end = start + 50
        digit_files = files[start:end]

        test_files_other.extend(digit_files[:50])

        
# Create dataset from other speakers
other_speaker_features , other_speaker_labels = features_and_labels(test_files_other)
other_ds = AudioDataSet(other_speaker_features, other_speaker_labels)
test_loader_other = DataLoader(other_ds, batch_size = batch_size, shuffle=False)

def predict_labels(dataloader, model):
    all_preds = []
    all_true = []

    # Iterate over dataset
    for X, y in dataloader:

        # Get model predicitions
        y_hat = model(X)
        predicted_class = torch.argmax(y_hat, dim=1) 

        # Save model predicted classes and corresponding labels
        all_preds.append(predicted_class)
        all_true.append(y.numpy().astype(int))

    return np.concatenate(all_true), np.concatenate(all_preds)

# %%
with torch.inference_mode():
    y_true, y_pred = predict_labels(test_loader_other, model)

cm = confusion_matrix(y_true, y_pred)

disp = sklearn.metrics.ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(number))
print("\nReport:\n", classification_report(y_true, y_pred, target_names=np.unique(number)))
disp.plot()
plt.title("Test set includes all speakers")
plt.savefig("DigitClassifierConfusion - All Speakers.png")
# Out:
# Report:
#                precision    recall  f1-score   support
#
#            0       0.55      0.52      0.54       950
#            1       0.38      0.41      0.39       950
#            2       0.51      0.37      0.43       950
#            3       0.55      0.20      0.29       950
#            4       0.61      0.44      0.51       950
#            5       0.35      0.44      0.39       950
#            6       0.65      0.80      0.72       950
#            7       0.50      0.61      0.55       950
#            8       0.70      0.76      0.73       950
#            9       0.33      0.46      0.38       950
#
#     accuracy                           0.50      9500
#    macro avg       0.51      0.50      0.49      9500
# weighted avg       0.51      0.50      0.49      9500

# %% [markdown]
# **USING ALL THE SPEAKERS AS PART OF TRAINING**

# %%
# Now to train the data using all of the speakers

unique_speakers = np.unique( speaker )
include_speakers_start = 0
include_speaker_end = 20
unique_speakers_sliced = unique_speakers[include_speakers_start:include_speaker_end]

speaker_dict = {}
for sp in unique_speakers_sliced:
    folder = f"./Data/{sp}"
    files = np.array(sorted(glob(f"{folder}/*.wav")))
    speaker_dict[folder] = files

train_files = []
test_files = []
val_files = []


for folder, files in speaker_dict.items():

    for digit in range(10):

        start = digit * 50
        end = start + 50
        digit_files = files[start:end]

        train_files.extend(digit_files[:40])
        test_files.extend(digit_files[40:45])
        val_files.extend(digit_files[45:])

# Create the features and labels
train_features , train_labels = features_and_labels(train_files)
test_features , test_labels = features_and_labels(test_files)
val_features , val_labels = features_and_labels(val_files)

# %%
# Create our datasets

train_ds = AudioDataSet(train_features, train_labels)
test_ds = AudioDataSet(test_features, test_labels)
val_ds = AudioDataSet(val_features, val_labels)

# %%
# Randomly shuffle the data with a batch size of 50

batch_size = 50

train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False) # No need to shuffle validation/test sets
test_loader  = DataLoader(test_ds,  batch_size=batch_size, shuffle=False) # No need to shuffle validation/test sets

# %%
# Intialise the model

model = ConvNet( _inChannels= frequency_time_size, _outChannels= 16, _kernelSize= 5, _numClasses=10 , _numBlocks=8 ,_activation=torch.nn.ReLU())
learning_rate = 0.001
optimiser = torch.optim.Adam(params=model.parameters())
loss_fn = torch.nn.CrossEntropyLoss()

# %%
# Define number of training epochs
epochs = 100

# Lists for monitoring training
train_loss_list, train_acc_list = [], []
val_loss_list, val_acc_list = [], []

# Loop for neural network training
for epoch in range(1, epochs + 1):
    
    train_loss, train_acc = train_one_epoch(train_loader, model, loss_fn, optimiser)

    if epoch % 5 == 0:

        # This disables gradient tracking in torch for the indented code
        # It isn't strictly neccessary but saves computational cost
        with torch.inference_mode():
            val_loss, val_acc = evaluate(val_loader, model, loss_fn)

        train_loss_list.append(train_loss)
        train_acc_list.append(train_acc)
        val_loss_list.append(val_loss)
        val_acc_list.append(val_acc)


        print(
            f"Epoch {epoch:02d} | "
            f"train loss {train_loss:.4f}, train acc {train_acc:.3f} | "
            f"val loss {val_loss:.4f}, val acc {val_acc:.3f}"
        )
# Out:
# Epoch 05 | train loss 0.2773, train acc 0.902 | val loss 0.3467, val acc 0.875
# Epoch 10 | train loss 0.1350, train acc 0.952 | val loss 0.1725, val acc 0.949
# Epoch 15 | train loss 0.0991, train acc 0.969 | val loss 0.1552, val acc 0.963
# Epoch 20 | train loss 0.0742, train acc 0.976 | val loss 0.1466, val acc 0.960
# Epoch 25 | train loss 0.0669, train acc 0.978 | val loss 0.1251, val acc 0.967
# Epoch 30 | train loss 0.0638, train acc 0.980 | val loss 0.1177, val acc 0.963
# Epoch 35 | train loss 0.0168, train acc 0.995 | val loss 0.1218, val acc 0.967
# Epoch 40 | train loss 0.0475, train acc 0.986 | val loss 0.1977, val acc 0.946
# Epoch 45 | train loss 0.0210, train acc 0.993 | val loss 0.1174, val acc 0.974
# Epoch 50 | train loss 0.0384, train acc 0.989 | val loss 0.1385, val acc 0.970
# Epoch 55 | train loss 0.0353, train acc 0.991 | val loss 0.1830, val acc 0.953
# Epoch 60 | train loss 0.0441, train acc 0.988 | val loss 0.0929, val acc 0.976
# Epoch 65 | train loss 0.0088, train acc 0.997 | val loss 0.1031, val acc 0.979
# Epoch 70 | train loss 0.0157, train acc 0.995 | val loss 0.1049, val acc 0.977
# Epoch 75 | train loss 0.0437, train acc 0.988 | val loss 0.1032, val acc 0.972
# Epoch 80 | train loss 0.0141, train acc 0.995 | val loss 0.1128, val acc 0.976
# Epoch 85 | train loss 0.0156, train acc 0.996 | val loss 0.1489, val acc 0.967
# Epoch 90 | train loss 0.0312, train acc 0.993 | val loss 0.2332, val acc 0.963
# Epoch 95 | train loss 0.0280, train acc 0.992 | val loss 0.0992, val acc 0.980
# Epoch 100 | train loss 0.0403, train acc 0.990 | val loss 0.1492, val acc 0.969

# %%
# This creates a range: 5,10,5 ...
plot_epochs = range(5, (len(train_loss_list) * 5) + 1, 5)

plt.subplot(1, 2, 1)
plt.plot(plot_epochs, train_loss_list, label="train")
plt.plot(plot_epochs, val_loss_list, label="validation")
plt.title("Loss")
plt.xlabel("Epoch")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(plot_epochs, train_acc_list, label="train")
plt.plot(plot_epochs, val_acc_list, label="validation")
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Create and display the confusion matrix

with torch.inference_mode():
    y_true, y_pred = predict_labels(test_loader, model)

cm = confusion_matrix(y_true, y_pred)

disp = sklearn.metrics.ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(number))
print("\nReport:\n", classification_report(y_true, y_pred, target_names=np.unique(number)))
disp.plot()
plt.title("Confusion Matrix - All Speakers in Training")
plt.savefig("DigitClassifierConfusion - All Speakers in Training.png")
# Out:
# Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       100
#            1       0.98      0.99      0.99       100
#            2       0.97      0.97      0.97       100
#            3       0.99      0.89      0.94       100
#            4       1.00      1.00      1.00       100
#            5       0.99      0.99      0.99       100
#            6       1.00      1.00      1.00       100
#            7       0.99      0.99      0.99       100
#            8       0.97      0.99      0.98       100
#            9       0.94      0.99      0.97       100
#
#     accuracy                           0.98      1000
#    macro avg       0.98      0.98      0.98      1000
# weighted avg       0.98      0.98      0.98      1000
