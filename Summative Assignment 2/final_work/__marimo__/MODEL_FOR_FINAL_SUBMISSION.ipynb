# %%
import marimo as mo

# %% [markdown]
# First, import all of the necessary packages

# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from torch import nn
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, classification_report
from sklearn.preprocessing import LabelEncoder
import librosa
import pathlib

# %% [markdown]
# Next, a csv that refernces your samples with audio effects applied.
#
# In total, 3 columns are vital:  <br>
# 1) new_file_path - This is the file path of your .wav file  <br>
# 2) effect_applied - The audio effect that you appplied to your audio sample  <br>
# 3) split - Set this as test

# %%
# Get a list of the files on your drive. Needs to be a CSV with the following columns

# I have supplied some test data
new_df_split = pd.read_csv(filepath_or_buffer=r"./new_df_split.csv")
new_df_split = new_df_split.drop(columns=['test_train_val','file_path','uuid4', 'instrument','wet_dry','parameter','parameter_value'])
new_df_split = new_df_split[new_df_split["split"] == "test"]

# %%
# Show the first 5 rows of your dataset
new_df_split.head()

# %% [markdown]
# Helper functions to run the model

# %%
# Summarise the features that we are going to use
def summarize_feature(values, feature_name, stats=("mean", "std")):
    stat_functions = {
        "mean": np.mean,
        "std": np.std,
        "min": np.min,
        "max": np.max,
    }

    flattened = np.asarray(values).ravel()
    summary = {}

    for stat_name in stats:
        if stat_name not in stat_functions:
            available_stats = ", ".join(sorted(stat_functions))
            raise ValueError(f"Unknown stat '{stat_name}'. Available stats: {available_stats}")

        summary[f"{feature_name}_{stat_name}"] = float(stat_functions[stat_name](flattened))

    return summary

# %%
# Extract the RMS energy
def extract_rms_features_from_signal(y, sr, stats=("mean", "std")):
    rms = librosa.feature.rms(y=y)
    return summarize_feature(rms, "rms_energy", stats=stats)

# %%
# Extract the spectral flatness
def extract_spectral_flatness_features_from_signal(y, sr, stats=("mean", "std")):
    spectral_flatness = librosa.feature.spectral_flatness(y=y)
    return summarize_feature(spectral_flatness, "spectral_flatness", stats=stats)

# %%
# All the feature extractors are collected here.
FEATURE_EXTRACTORS = {
    "rms_energy": extract_rms_features_from_signal,
    "spectral_flatness": extract_spectral_flatness_features_from_signal,
}

# %%
# Extract the audio features and add them to a dataframe
def extract_audio_features(audio_path, feature_sets=("baseline",), sr=22050, mono=True, feature_kwargs=None):
    if isinstance(feature_sets, str):
        feature_sets = [feature_sets]

    feature_kwargs = feature_kwargs or {}
    y, sr = librosa.load(audio_path, sr=sr, mono=mono)

    features = {}

    for feature_set in feature_sets:
        if feature_set not in FEATURE_EXTRACTORS:
            available_feature_sets = ", ".join(sorted(FEATURE_EXTRACTORS))
            raise ValueError(
                f"Unknown feature set '{feature_set}'. Available feature sets: {available_feature_sets}"
            )

        extractor_kwargs = feature_kwargs.get(feature_set, {})
        feature_values = FEATURE_EXTRACTORS[feature_set](y=y, sr=sr, **extractor_kwargs)

        duplicate_keys = set(features).intersection(feature_values)
        if duplicate_keys:
            duplicate_keys_str = ", ".join(sorted(duplicate_keys))
            raise ValueError(f"Duplicate feature names found: {duplicate_keys_str}")

        features.update(feature_values)

    return features

# %%
# Loop through the audio files and build one big feature table.
def build_feature_dataframe(
    new_df,
    audio_col="new_file_path",
    feature_sets=("baseline",),
    sr=22050,
    mono=True,
    feature_kwargs=None,
    verbose=True,
    raise_on_error=False,
):
    new_df = new_df.reset_index(drop=True)
    rows = []
    total_samples = len(new_df)

    for i, row in new_df.iterrows():
        if verbose:
            print(f"Processing sample {i} / {total_samples}")

        audio_path = pathlib.Path(row[audio_col])

        try:
            feat_dict = extract_audio_features(
                audio_path=audio_path,
                feature_sets=feature_sets,
                sr=sr,
                mono=mono,
                feature_kwargs=feature_kwargs,
            )
            out_row = row.to_dict()
            out_row.update(feat_dict)
            rows.append(out_row)
        except Exception as e:
            print(f"Failed on {audio_path}: {e}")
            if raise_on_error:
                raise

    return pd.DataFrame(rows)

# %% [markdown]
# We now need to craete a datafram for the model to use

# %%
# Pick which features to turn on here.
FEATURE_CONFIG = {'feature_sets': ('rms_energy', 'spectral_flatness'), 'feature_kwargs': {'rms_energy': {'stats': ('mean', 'std')}, 'spectral_flatness': {'stats': ('mean', 'std')}}}

# This is the dataframe that the model will use
feature_df = build_feature_dataframe(new_df_split, audio_col='new_file_path', **FEATURE_CONFIG)
# Out:
# Processing sample 0 / 1050
# Processing sample 1 / 1050
# Processing sample 2 / 1050
# Processing sample 3 / 1050
# Processing sample 4 / 1050
# Processing sample 5 / 1050
# Processing sample 6 / 1050
# Processing sample 7 / 1050
# Processing sample 8 / 1050
# Processing sample 9 / 1050
# Processing sample 10 / 1050
# Processing sample 11 / 1050
# Processing sample 12 / 1050
# Processing sample 13 / 1050
# Processing sample 14 / 1050
# Processing sample 15 / 1050
# Processing sample 16 / 1050
# Processing sample 17 / 1050
# Processing sample 18 / 1050
# Processing sample 19 / 1050
# Processing sample 20 / 1050
# Processing sample 21 / 1050
# Processing sample 22 / 1050
# Processing sample 23 / 1050
# Processing sample 24 / 1050
# Processing sample 25 / 1050
# Processing sample 26 / 1050
# Processing sample 27 / 1050
# Processing sample 28 / 1050
# Processing sample 29 / 1050
# Processing sample 30 / 1050
# Processing sample 31 / 1050
# Processing sample 32 / 1050
# Processing sample 33 / 1050
# Processing sample 34 / 1050
# Processing sample 35 / 1050
# Processing sample 36 / 1050
# Processing sample 37 / 1050
# Processing sample 38 / 1050
# Processing sample 39 / 1050
# Processing sample 40 / 1050
# Processing sample 41 / 1050
# Processing sample 42 / 1050
# Processing sample 43 / 1050
# Processing sample 44 / 1050
# Processing sample 45 / 1050
# Processing sample 46 / 1050
# Processing sample 47 / 1050
# Processing sample 48 / 1050
# Processing sample 49 / 1050
# Processing sample 50 / 1050
# Processing sample 51 / 1050
# Processing sample 52 / 1050
# Processing sample 53 / 1050
# Processing sample 54 / 1050
# Processing sample 55 / 1050
# Processing sample 56 / 1050
# Processing sample 57 / 1050
# Processing sample 58 / 1050
# Processing sample 59 / 1050
# Processing sample 60 / 1050
# Processing sample 61 / 1050
# Processing sample 62 / 1050
# Processing sample 63 / 1050
# Processing sample 64 / 1050
# Processing sample 65 / 1050
# Processing sample 66 / 1050
# Processing sample 67 / 1050
# Processing sample 68 / 1050
# Processing sample 69 / 1050
# Processing sample 70 / 1050
# Processing sample 71 / 1050
# Processing sample 72 / 1050
# Processing sample 73 / 1050
# Processing sample 74 / 1050
# Processing sample 75 / 1050
# Processing sample 76 / 1050
# Processing sample 77 / 1050
# Processing sample 78 / 1050
# Processing sample 79 / 1050
# Processing sample 80 / 1050
# Processing sample 81 / 1050
# Processing sample 82 / 1050
# Processing sample 83 / 1050
# Processing sample 84 / 1050
# Processing sample 85 / 1050
# Processing sample 86 / 1050
# Processing sample 87 / 1050
# Processing sample 88 / 1050
# Processing sample 89 / 1050
# Processing sample 90 / 1050
# Processing sample 91 / 1050
# Processing sample 92 / 1050
# Processing sample 93 / 1050
# Processing sample 94 / 1050
# Processing sample 95 / 1050
# Processing sample 96 / 1050
# Processing sample 97 / 1050
# Processing sample 98 / 1050
# Processing sample 99 / 1050
# Processing sample 100 / 1050
# Processing sample 101 / 1050
# Processing sample 102 / 1050
# Processing sample 103 / 1050
# Processing sample 104 / 1050
# Processing sample 105 / 1050
# Processing sample 106 / 1050
# Processing sample 107 / 1050
# Processing sample 108 / 1050
# Processing sample 109 / 1050
# Processing sample 110 / 1050
# Processing sample 111 / 1050
# Processing sample 112 / 1050
# Processing sample 113 / 1050
# Processing sample 114 / 1050
# Processing sample 115 / 1050
# Processing sample 116 / 1050
# Processing sample 117 / 1050
# Processing sample 118 / 1050
# Processing sample 119 / 1050
# Processing sample 120 / 1050
# Processing sample 121 / 1050
# Processing sample 122 / 1050
# Processing sample 123 / 1050
# Processing sample 124 / 1050
# Processing sample 125 / 1050
# Processing sample 126 / 1050
# Processing sample 127 / 1050
# Processing sample 128 / 1050
# Processing sample 129 / 1050
# Processing sample 130 / 1050
# Processing sample 131 / 1050
# Processing sample 132 / 1050
# Processing sample 133 / 1050
# Processing sample 134 / 1050
# Processing sample 135 / 1050
# Processing sample 136 / 1050
# Processing sample 137 / 1050
# Processing sample 138 / 1050
# Processing sample 139 / 1050
# Processing sample 140 / 1050
# Processing sample 141 / 1050
# Processing sample 142 / 1050
# Processing sample 143 / 1050
# Processing sample 144 / 1050
# Processing sample 145 / 1050
# Processing sample 146 / 1050
# Processing sample 147 / 1050
# Processing sample 148 / 1050
# Processing sample 149 / 1050
# Processing sample 150 / 1050
# Processing sample 151 / 1050
# Processing sample 152 / 1050
# Processing sample 153 / 1050
# Processing sample 154 / 1050
# Processing sample 155 / 1050
# Processing sample 156 / 1050
# Processing sample 157 / 1050
# Processing sample 158 / 1050
# Processing sample 159 / 1050
# Processing sample 160 / 1050
# Processing sample 161 / 1050
# Processing sample 162 / 1050
# Processing sample 163 / 1050
# Processing sample 164 / 1050
# Processing sample 165 / 1050
# Processing sample 166 / 1050
# Processing sample 167 / 1050
# Processing sample 168 / 1050
# Processing sample 169 / 1050
# Processing sample 170 / 1050
# Processing sample 171 / 1050
# Processing sample 172 / 1050
# Processing sample 173 / 1050
# Processing sample 174 / 1050
# Processing sample 175 / 1050
# Processing sample 176 / 1050
# Processing sample 177 / 1050
# Processing sample 178 / 1050
# Processing sample 179 / 1050
# Processing sample 180 / 1050
# Processing sample 181 / 1050
# Processing sample 182 / 1050
# Processing sample 183 / 1050
# Processing sample 184 / 1050
# Processing sample 185 / 1050
# Processing sample 186 / 1050
# Processing sample 187 / 1050
# Processing sample 188 / 1050
# Processing sample 189 / 1050
# Processing sample 190 / 1050
# Processing sample 191 / 1050
# Processing sample 192 / 1050
# Processing sample 193 / 1050
# Processing sample 194 / 1050
# Processing sample 195 / 1050
# Processing sample 196 / 1050
# Processing sample 197 / 1050
# Processing sample 198 / 1050
# Processing sample 199 / 1050
# Processing sample 200 / 1050
# Processing sample 201 / 1050
# Processing sample 202 / 1050
# Processing sample 203 / 1050
# Processing sample 204 / 1050
# Processing sample 205 / 1050
# Processing sample 206 / 1050
# Processing sample 207 / 1050
# Processing sample 208 / 1050
# Processing sample 209 / 1050
# Processing sample 210 / 1050
# Processing sample 211 / 1050
# Processing sample 212 / 1050
# Processing sample 213 / 1050
# Processing sample 214 / 1050
# Processing sample 215 / 1050
# Processing sample 216 / 1050
# Processing sample 217 / 1050
# Processing sample 218 / 1050
# Processing sample 219 / 1050
# Processing sample 220 / 1050
# Processing sample 221 / 1050
# Processing sample 222 / 1050
# Processing sample 223 / 1050
# Processing sample 224 / 1050
# Processing sample 225 / 1050
# Processing sample 226 / 1050
# Processing sample 227 / 1050
# Processing sample 228 / 1050
# Processing sample 229 / 1050
# Processing sample 230 / 1050
# Processing sample 231 / 1050
# Processing sample 232 / 1050
# Processing sample 233 / 1050
# Processing sample 234 / 1050
# Processing sample 235 / 1050
# Processing sample 236 / 1050
# Processing sample 237 / 1050
# Processing sample 238 / 1050
# Processing sample 239 / 1050
# Processing sample 240 / 1050
# Processing sample 241 / 1050
# Processing sample 242 / 1050
# Processing sample 243 / 1050
# Processing sample 244 / 1050
# Processing sample 245 / 1050
# Processing sample 246 / 1050
# Processing sample 247 / 1050
# Processing sample 248 / 1050
# Processing sample 249 / 1050
# Processing sample 250 / 1050
# Processing sample 251 / 1050
# Processing sample 252 / 1050
# Processing sample 253 / 1050
# Processing sample 254 / 1050
# Processing sample 255 / 1050
# Processing sample 256 / 1050
# Processing sample 257 / 1050
# Processing sample 258 / 1050
# Processing sample 259 / 1050
# Processing sample 260 / 1050
# Processing sample 261 / 1050
# Processing sample 262 / 1050
# Processing sample 263 / 1050
# Processing sample 264 / 1050
# Processing sample 265 / 1050
# Processing sample 266 / 1050
# Processing sample 267 / 1050
# Processing sample 268 / 1050
# Processing sample 269 / 1050
# Processing sample 270 / 1050
# Processing sample 271 / 1050
# Processing sample 272 / 1050
# Processing sample 273 / 1050
# Processing sample 274 / 1050
# Processing sample 275 / 1050
# Processing sample 276 / 1050
# Processing sample 277 / 1050
# Processing sample 278 / 1050
# Processing sample 279 / 1050
# Processing sample 280 / 1050
# Processing sample 281 / 1050
# Processing sample 282 / 1050
# Processing sample 283 / 1050
# Processing sample 284 / 1050
# Processing sample 285 / 1050
# Processing sample 286 / 1050
# Processing sample 287 / 1050
# Processing sample 288 / 1050
# Processing sample 289 / 1050
# Processing sample 290 / 1050
# Processing sample 291 / 1050
# Processing sample 292 / 1050
# Processing sample 293 / 1050
# Processing sample 294 / 1050
# Processing sample 295 / 1050
# Processing sample 296 / 1050
# Processing sample 297 / 1050
# Processing sample 298 / 1050
# Processing sample 299 / 1050
# Processing sample 300 / 1050
# Processing sample 301 / 1050
# Processing sample 302 / 1050
# Processing sample 303 / 1050
# Processing sample 304 / 1050
# Processing sample 305 / 1050
# Processing sample 306 / 1050
# Processing sample 307 / 1050
# Processing sample 308 / 1050
# Processing sample 309 / 1050
# Processing sample 310 / 1050
# Processing sample 311 / 1050
# Processing sample 312 / 1050
# Processing sample 313 / 1050
# Processing sample 314 / 1050
# Processing sample 315 / 1050
# Processing sample 316 / 1050
# Processing sample 317 / 1050
# Processing sample 318 / 1050
# Processing sample 319 / 1050
# Processing sample 320 / 1050
# Processing sample 321 / 1050
# Processing sample 322 / 1050
# Processing sample 323 / 1050
# Processing sample 324 / 1050
# Processing sample 325 / 1050
# Processing sample 326 / 1050
# Processing sample 327 / 1050
# Processing sample 328 / 1050
# Processing sample 329 / 1050
# Processing sample 330 / 1050
# Processing sample 331 / 1050
# Processing sample 332 / 1050
# Processing sample 333 / 1050
# Processing sample 334 / 1050
# Processing sample 335 / 1050
# Processing sample 336 / 1050
# Processing sample 337 / 1050
# Processing sample 338 / 1050
# Processing sample 339 / 1050
# Processing sample 340 / 1050
# Processing sample 341 / 1050
# Processing sample 342 / 1050
# Processing sample 343 / 1050
# Processing sample 344 / 1050
# Processing sample 345 / 1050
# Processing sample 346 / 1050
# Processing sample 347 / 1050
# Processing sample 348 / 1050
# Processing sample 349 / 1050
# Processing sample 350 / 1050
# Processing sample 351 / 1050
# Processing sample 352 / 1050
# Processing sample 353 / 1050
# Processing sample 354 / 1050
# Processing sample 355 / 1050
# Processing sample 356 / 1050
# Processing sample 357 / 1050
# Processing sample 358 / 1050
# Processing sample 359 / 1050
# Processing sample 360 / 1050
# Processing sample 361 / 1050
# Processing sample 362 / 1050
# Processing sample 363 / 1050
# Processing sample 364 / 1050
# Processing sample 365 / 1050
# Processing sample 366 / 1050
# Processing sample 367 / 1050
# Processing sample 368 / 1050
# Processing sample 369 / 1050
# Processing sample 370 / 1050
# Processing sample 371 / 1050
# Processing sample 372 / 1050
# Processing sample 373 / 1050
# Processing sample 374 / 1050
# Processing sample 375 / 1050
# Processing sample 376 / 1050
# Processing sample 377 / 1050
# Processing sample 378 / 1050
# Processing sample 379 / 1050
# Processing sample 380 / 1050
# Processing sample 381 / 1050
# Processing sample 382 / 1050
# Processing sample 383 / 1050
# Processing sample 384 / 1050
# Processing sample 385 / 1050
# Processing sample 386 / 1050
# Processing sample 387 / 1050
# Processing sample 388 / 1050
# Processing sample 389 / 1050
# Processing sample 390 / 1050
# Processing sample 391 / 1050
# Processing sample 392 / 1050
# Processing sample 393 / 1050
# Processing sample 394 / 1050
# Processing sample 395 / 1050
# Processing sample 396 / 1050
# Processing sample 397 / 1050
# Processing sample 398 / 1050
# Processing sample 399 / 1050
# Processing sample 400 / 1050
# Processing sample 401 / 1050
# Processing sample 402 / 1050
# Processing sample 403 / 1050
# Processing sample 404 / 1050
# Processing sample 405 / 1050
# Processing sample 406 / 1050
# Processing sample 407 / 1050
# Processing sample 408 / 1050
# Processing sample 409 / 1050
# Processing sample 410 / 1050
# Processing sample 411 / 1050
# Processing sample 412 / 1050
# Processing sample 413 / 1050
# Processing sample 414 / 1050
# Processing sample 415 / 1050
# Processing sample 416 / 1050
# Processing sample 417 / 1050
# Processing sample 418 / 1050
# Processing sample 419 / 1050
# Processing sample 420 / 1050
# Processing sample 421 / 1050
# Processing sample 422 / 1050
# Processing sample 423 / 1050
# Processing sample 424 / 1050
# Processing sample 425 / 1050
# Processing sample 426 / 1050
# Processing sample 427 / 1050
# Processing sample 428 / 1050
# Processing sample 429 / 1050
# Processing sample 430 / 1050
# Processing sample 431 / 1050
# Processing sample 432 / 1050
# Processing sample 433 / 1050
# Processing sample 434 / 1050
# Processing sample 435 / 1050
# Processing sample 436 / 1050
# Processing sample 437 / 1050
# Processing sample 438 / 1050
# Processing sample 439 / 1050
# Processing sample 440 / 1050
# Processing sample 441 / 1050
# Processing sample 442 / 1050
# Processing sample 443 / 1050
# Processing sample 444 / 1050
# Processing sample 445 / 1050
# Processing sample 446 / 1050
# Processing sample 447 / 1050
# Processing sample 448 / 1050
# Processing sample 449 / 1050
# Processing sample 450 / 1050
# Processing sample 451 / 1050
# Processing sample 452 / 1050
# Processing sample 453 / 1050
# Processing sample 454 / 1050
# Processing sample 455 / 1050
# Processing sample 456 / 1050
# Processing sample 457 / 1050
# Processing sample 458 / 1050
# Processing sample 459 / 1050
# Processing sample 460 / 1050
# Processing sample 461 / 1050
# Processing sample 462 / 1050
# Processing sample 463 / 1050
# Processing sample 464 / 1050
# Processing sample 465 / 1050
# Processing sample 466 / 1050
# Processing sample 467 / 1050
# Processing sample 468 / 1050
# Processing sample 469 / 1050
# Processing sample 470 / 1050
# Processing sample 471 / 1050
# Processing sample 472 / 1050
# Processing sample 473 / 1050
# Processing sample 474 / 1050
# Processing sample 475 / 1050
# Processing sample 476 / 1050
# Processing sample 477 / 1050
# Processing sample 478 / 1050
# Processing sample 479 / 1050
# Processing sample 480 / 1050
# Processing sample 481 / 1050
# Processing sample 482 / 1050
# Processing sample 483 / 1050
# Processing sample 484 / 1050
# Processing sample 485 / 1050
# Processing sample 486 / 1050
# Processing sample 487 / 1050
# Processing sample 488 / 1050
# Processing sample 489 / 1050
# Processing sample 490 / 1050
# Processing sample 491 / 1050
# Processing sample 492 / 1050
# Processing sample 493 / 1050
# Processing sample 494 / 1050
# Processing sample 495 / 1050
# Processing sample 496 / 1050
# Processing sample 497 / 1050
# Processing sample 498 / 1050
# Processing sample 499 / 1050
# Processing sample 500 / 1050
# Processing sample 501 / 1050
# Processing sample 502 / 1050
# Processing sample 503 / 1050
# Processing sample 504 / 1050
# Processing sample 505 / 1050
# Processing sample 506 / 1050
# Processing sample 507 / 1050
# Processing sample 508 / 1050
# Processing sample 509 / 1050
# Processing sample 510 / 1050
# Processing sample 511 / 1050
# Processing sample 512 / 1050
# Processing sample 513 / 1050
# Processing sample 514 / 1050
# Processing sample 515 / 1050
# Processing sample 516 / 1050
# Processing sample 517 / 1050
# Processing sample 518 / 1050
# Processing sample 519 / 1050
# Processing sample 520 / 1050
# Processing sample 521 / 1050
# Processing sample 522 / 1050
# Processing sample 523 / 1050
# Processing sample 524 / 1050
# Processing sample 525 / 1050
# Processing sample 526 / 1050
# Processing sample 527 / 1050
# Processing sample 528 / 1050
# Processing sample 529 / 1050
# Processing sample 530 / 1050
# Processing sample 531 / 1050
# Processing sample 532 / 1050
# Processing sample 533 / 1050
# Processing sample 534 / 1050
# Processing sample 535 / 1050
# Processing sample 536 / 1050
# Processing sample 537 / 1050
# Processing sample 538 / 1050
# Processing sample 539 / 1050
# Processing sample 540 / 1050
# Processing sample 541 / 1050
# Processing sample 542 / 1050
# Processing sample 543 / 1050
# Processing sample 544 / 1050
# Processing sample 545 / 1050
# Processing sample 546 / 1050
# Processing sample 547 / 1050
# Processing sample 548 / 1050
# Processing sample 549 / 1050
# Processing sample 550 / 1050
# Processing sample 551 / 1050
# Processing sample 552 / 1050
# Processing sample 553 / 1050
# Processing sample 554 / 1050
# Processing sample 555 / 1050
# Processing sample 556 / 1050
# Processing sample 557 / 1050
# Processing sample 558 / 1050
# Processing sample 559 / 1050
# Processing sample 560 / 1050
# Processing sample 561 / 1050
# Processing sample 562 / 1050
# Processing sample 563 / 1050
# Processing sample 564 / 1050
# Processing sample 565 / 1050
# Processing sample 566 / 1050
# Processing sample 567 / 1050
# Processing sample 568 / 1050
# Processing sample 569 / 1050
# Processing sample 570 / 1050
# Processing sample 571 / 1050
# Processing sample 572 / 1050
# Processing sample 573 / 1050
# Processing sample 574 / 1050
# Processing sample 575 / 1050
# Processing sample 576 / 1050
# Processing sample 577 / 1050
# Processing sample 578 / 1050
# Processing sample 579 / 1050
# Processing sample 580 / 1050
# Processing sample 581 / 1050
# Processing sample 582 / 1050
# Processing sample 583 / 1050
# Processing sample 584 / 1050
# Processing sample 585 / 1050
# Processing sample 586 / 1050
# Processing sample 587 / 1050
# Processing sample 588 / 1050
# Processing sample 589 / 1050
# Processing sample 590 / 1050
# Processing sample 591 / 1050
# Processing sample 592 / 1050
# Processing sample 593 / 1050
# Processing sample 594 / 1050
# Processing sample 595 / 1050
# Processing sample 596 / 1050
# Processing sample 597 / 1050
# Processing sample 598 / 1050
# Processing sample 599 / 1050
# Processing sample 600 / 1050
# Processing sample 601 / 1050
# Processing sample 602 / 1050
# Processing sample 603 / 1050
# Processing sample 604 / 1050
# Processing sample 605 / 1050
# Processing sample 606 / 1050
# Processing sample 607 / 1050
# Processing sample 608 / 1050
# Processing sample 609 / 1050
# Processing sample 610 / 1050
# Processing sample 611 / 1050
# Processing sample 612 / 1050
# Processing sample 613 / 1050
# Processing sample 614 / 1050
# Processing sample 615 / 1050
# Processing sample 616 / 1050
# Processing sample 617 / 1050
# Processing sample 618 / 1050
# Processing sample 619 / 1050
# Processing sample 620 / 1050
# Processing sample 621 / 1050
# Processing sample 622 / 1050
# Processing sample 623 / 1050
# Processing sample 624 / 1050
# Processing sample 625 / 1050
# Processing sample 626 / 1050
# Processing sample 627 / 1050
# Processing sample 628 / 1050
# Processing sample 629 / 1050
# Processing sample 630 / 1050
# Processing sample 631 / 1050
# Processing sample 632 / 1050
# Processing sample 633 / 1050
# Processing sample 634 / 1050
# Processing sample 635 / 1050
# Processing sample 636 / 1050
# Processing sample 637 / 1050
# Processing sample 638 / 1050
# Processing sample 639 / 1050
# Processing sample 640 / 1050
# Processing sample 641 / 1050
# Processing sample 642 / 1050
# Processing sample 643 / 1050
# Processing sample 644 / 1050
# Processing sample 645 / 1050
# Processing sample 646 / 1050
# Processing sample 647 / 1050
# Processing sample 648 / 1050
# Processing sample 649 / 1050
# Processing sample 650 / 1050
# Processing sample 651 / 1050
# Processing sample 652 / 1050
# Processing sample 653 / 1050
# Processing sample 654 / 1050
# Processing sample 655 / 1050
# Processing sample 656 / 1050
# Processing sample 657 / 1050
# Processing sample 658 / 1050
# Processing sample 659 / 1050
# Processing sample 660 / 1050
# Processing sample 661 / 1050
# Processing sample 662 / 1050
# Processing sample 663 / 1050
# Processing sample 664 / 1050
# Processing sample 665 / 1050
# Processing sample 666 / 1050
# Processing sample 667 / 1050
# Processing sample 668 / 1050
# Processing sample 669 / 1050
# Processing sample 670 / 1050
# Processing sample 671 / 1050
# Processing sample 672 / 1050
# Processing sample 673 / 1050
# Processing sample 674 / 1050
# Processing sample 675 / 1050
# Processing sample 676 / 1050
# Processing sample 677 / 1050
# Processing sample 678 / 1050
# Processing sample 679 / 1050
# Processing sample 680 / 1050
# Processing sample 681 / 1050
# Processing sample 682 / 1050
# Processing sample 683 / 1050
# Processing sample 684 / 1050
# Processing sample 685 / 1050
# Processing sample 686 / 1050
# Processing sample 687 / 1050
# Processing sample 688 / 1050
# Processing sample 689 / 1050
# Processing sample 690 / 1050
# Processing sample 691 / 1050
# Processing sample 692 / 1050
# Processing sample 693 / 1050
# Processing sample 694 / 1050
# Processing sample 695 / 1050
# Processing sample 696 / 1050
# Processing sample 697 / 1050
# Processing sample 698 / 1050
# Processing sample 699 / 1050
# Processing sample 700 / 1050
# Processing sample 701 / 1050
# Processing sample 702 / 1050
# Processing sample 703 / 1050
# Processing sample 704 / 1050
# Processing sample 705 / 1050
# Processing sample 706 / 1050
# Processing sample 707 / 1050
# Processing sample 708 / 1050
# Processing sample 709 / 1050
# Processing sample 710 / 1050
# Processing sample 711 / 1050
# Processing sample 712 / 1050
# Processing sample 713 / 1050
# Processing sample 714 / 1050
# Processing sample 715 / 1050
# Processing sample 716 / 1050
# Processing sample 717 / 1050
# Processing sample 718 / 1050
# Processing sample 719 / 1050
# Processing sample 720 / 1050
# Processing sample 721 / 1050
# Processing sample 722 / 1050
# Processing sample 723 / 1050
# Processing sample 724 / 1050
# Processing sample 725 / 1050
# Processing sample 726 / 1050
# Processing sample 727 / 1050
# Processing sample 728 / 1050
# Processing sample 729 / 1050
# Processing sample 730 / 1050
# Processing sample 731 / 1050
# Processing sample 732 / 1050
# Processing sample 733 / 1050
# Processing sample 734 / 1050
# Processing sample 735 / 1050
# Processing sample 736 / 1050
# Processing sample 737 / 1050
# Processing sample 738 / 1050
# Processing sample 739 / 1050
# Processing sample 740 / 1050
# Processing sample 741 / 1050
# Processing sample 742 / 1050
# Processing sample 743 / 1050
# Processing sample 744 / 1050
# Processing sample 745 / 1050
# Processing sample 746 / 1050
# Processing sample 747 / 1050
# Processing sample 748 / 1050
# Processing sample 749 / 1050
# Processing sample 750 / 1050
# Processing sample 751 / 1050
# Processing sample 752 / 1050
# Processing sample 753 / 1050
# Processing sample 754 / 1050
# Processing sample 755 / 1050
# Processing sample 756 / 1050
# Processing sample 757 / 1050
# Processing sample 758 / 1050
# Processing sample 759 / 1050
# Processing sample 760 / 1050
# Processing sample 761 / 1050
# Processing sample 762 / 1050
# Processing sample 763 / 1050
# Processing sample 764 / 1050
# Processing sample 765 / 1050
# Processing sample 766 / 1050
# Processing sample 767 / 1050
# Processing sample 768 / 1050
# Processing sample 769 / 1050
# Processing sample 770 / 1050
# Processing sample 771 / 1050
# Processing sample 772 / 1050
# Processing sample 773 / 1050
# Processing sample 774 / 1050
# Processing sample 775 / 1050
# Processing sample 776 / 1050
# Processing sample 777 / 1050
# Processing sample 778 / 1050
# Processing sample 779 / 1050
# Processing sample 780 / 1050
# Processing sample 781 / 1050
# Processing sample 782 / 1050
# Processing sample 783 / 1050
# Processing sample 784 / 1050
# Processing sample 785 / 1050
# Processing sample 786 / 1050
# Processing sample 787 / 1050
# Processing sample 788 / 1050
# Processing sample 789 / 1050
# Processing sample 790 / 1050
# Processing sample 791 / 1050
# Processing sample 792 / 1050
# Processing sample 793 / 1050
# Processing sample 794 / 1050
# Processing sample 795 / 1050
# Processing sample 796 / 1050
# Processing sample 797 / 1050
# Processing sample 798 / 1050
# Processing sample 799 / 1050
# Processing sample 800 / 1050
# Processing sample 801 / 1050
# Processing sample 802 / 1050
# Processing sample 803 / 1050
# Processing sample 804 / 1050
# Processing sample 805 / 1050
# Processing sample 806 / 1050
# Processing sample 807 / 1050
# Processing sample 808 / 1050
# Processing sample 809 / 1050
# Processing sample 810 / 1050
# Processing sample 811 / 1050
# Processing sample 812 / 1050
# Processing sample 813 / 1050
# Processing sample 814 / 1050
# Processing sample 815 / 1050
# Processing sample 816 / 1050
# Processing sample 817 / 1050
# Processing sample 818 / 1050
# Processing sample 819 / 1050
# Processing sample 820 / 1050
# Processing sample 821 / 1050
# Processing sample 822 / 1050
# Processing sample 823 / 1050
# Processing sample 824 / 1050
# Processing sample 825 / 1050
# Processing sample 826 / 1050
# Processing sample 827 / 1050
# Processing sample 828 / 1050
# Processing sample 829 / 1050
# Processing sample 830 / 1050
# Processing sample 831 / 1050
# Processing sample 832 / 1050
# Processing sample 833 / 1050
# Processing sample 834 / 1050
# Processing sample 835 / 1050
# Processing sample 836 / 1050
# Processing sample 837 / 1050
# Processing sample 838 / 1050
# Processing sample 839 / 1050
# Processing sample 840 / 1050
# Processing sample 841 / 1050
# Processing sample 842 / 1050
# Processing sample 843 / 1050
# Processing sample 844 / 1050
# Processing sample 845 / 1050
# Processing sample 846 / 1050
# Processing sample 847 / 1050
# Processing sample 848 / 1050
# Processing sample 849 / 1050
# Processing sample 850 / 1050
# Processing sample 851 / 1050
# Processing sample 852 / 1050
# Processing sample 853 / 1050
# Processing sample 854 / 1050
# Processing sample 855 / 1050
# Processing sample 856 / 1050
# Processing sample 857 / 1050
# Processing sample 858 / 1050
# Processing sample 859 / 1050
# Processing sample 860 / 1050
# Processing sample 861 / 1050
# Processing sample 862 / 1050
# Processing sample 863 / 1050
# Processing sample 864 / 1050
# Processing sample 865 / 1050
# Processing sample 866 / 1050
# Processing sample 867 / 1050
# Processing sample 868 / 1050
# Processing sample 869 / 1050
# Processing sample 870 / 1050
# Processing sample 871 / 1050
# Processing sample 872 / 1050
# Processing sample 873 / 1050
# Processing sample 874 / 1050
# Processing sample 875 / 1050
# Processing sample 876 / 1050
# Processing sample 877 / 1050
# Processing sample 878 / 1050
# Processing sample 879 / 1050
# Processing sample 880 / 1050
# Processing sample 881 / 1050
# Processing sample 882 / 1050
# Processing sample 883 / 1050
# Processing sample 884 / 1050
# Processing sample 885 / 1050
# Processing sample 886 / 1050
# Processing sample 887 / 1050
# Processing sample 888 / 1050
# Processing sample 889 / 1050
# Processing sample 890 / 1050
# Processing sample 891 / 1050
# Processing sample 892 / 1050
# Processing sample 893 / 1050
# Processing sample 894 / 1050
# Processing sample 895 / 1050
# Processing sample 896 / 1050
# Processing sample 897 / 1050
# Processing sample 898 / 1050
# Processing sample 899 / 1050
# Processing sample 900 / 1050
# Processing sample 901 / 1050
# Processing sample 902 / 1050
# Processing sample 903 / 1050
# Processing sample 904 / 1050
# Processing sample 905 / 1050
# Processing sample 906 / 1050
# Processing sample 907 / 1050
# Processing sample 908 / 1050
# Processing sample 909 / 1050
# Processing sample 910 / 1050
# Processing sample 911 / 1050
# Processing sample 912 / 1050
# Processing sample 913 / 1050
# Processing sample 914 / 1050
# Processing sample 915 / 1050
# Processing sample 916 / 1050
# Processing sample 917 / 1050
# Processing sample 918 / 1050
# Processing sample 919 / 1050
# Processing sample 920 / 1050
# Processing sample 921 / 1050
# Processing sample 922 / 1050
# Processing sample 923 / 1050
# Processing sample 924 / 1050
# Processing sample 925 / 1050
# Processing sample 926 / 1050
# Processing sample 927 / 1050
# Processing sample 928 / 1050
# Processing sample 929 / 1050
# Processing sample 930 / 1050
# Processing sample 931 / 1050
# Processing sample 932 / 1050
# Processing sample 933 / 1050
# Processing sample 934 / 1050
# Processing sample 935 / 1050
# Processing sample 936 / 1050
# Processing sample 937 / 1050
# Processing sample 938 / 1050
# Processing sample 939 / 1050
# Processing sample 940 / 1050
# Processing sample 941 / 1050
# Processing sample 942 / 1050
# Processing sample 943 / 1050
# Processing sample 944 / 1050
# Processing sample 945 / 1050
# Processing sample 946 / 1050
# Processing sample 947 / 1050
# Processing sample 948 / 1050
# Processing sample 949 / 1050
# Processing sample 950 / 1050
# Processing sample 951 / 1050
# Processing sample 952 / 1050
# Processing sample 953 / 1050
# Processing sample 954 / 1050
# Processing sample 955 / 1050
# Processing sample 956 / 1050
# Processing sample 957 / 1050
# Processing sample 958 / 1050
# Processing sample 959 / 1050
# Processing sample 960 / 1050
# Processing sample 961 / 1050
# Processing sample 962 / 1050
# Processing sample 963 / 1050
# Processing sample 964 / 1050
# Processing sample 965 / 1050
# Processing sample 966 / 1050
# Processing sample 967 / 1050
# Processing sample 968 / 1050
# Processing sample 969 / 1050
# Processing sample 970 / 1050
# Processing sample 971 / 1050
# Processing sample 972 / 1050
# Processing sample 973 / 1050
# Processing sample 974 / 1050
# Processing sample 975 / 1050
# Processing sample 976 / 1050
# Processing sample 977 / 1050
# Processing sample 978 / 1050
# Processing sample 979 / 1050
# Processing sample 980 / 1050
# Processing sample 981 / 1050
# Processing sample 982 / 1050
# Processing sample 983 / 1050
# Processing sample 984 / 1050
# Processing sample 985 / 1050
# Processing sample 986 / 1050
# Processing sample 987 / 1050
# Processing sample 988 / 1050
# Processing sample 989 / 1050
# Processing sample 990 / 1050
# Processing sample 991 / 1050
# Processing sample 992 / 1050
# Processing sample 993 / 1050
# Processing sample 994 / 1050
# Processing sample 995 / 1050
# Processing sample 996 / 1050
# Processing sample 997 / 1050
# Processing sample 998 / 1050
# Processing sample 999 / 1050
# Processing sample 1000 / 1050
# Processing sample 1001 / 1050
# Processing sample 1002 / 1050
# Processing sample 1003 / 1050
# Processing sample 1004 / 1050
# Processing sample 1005 / 1050
# Processing sample 1006 / 1050
# Processing sample 1007 / 1050
# Processing sample 1008 / 1050
# Processing sample 1009 / 1050
# Processing sample 1010 / 1050
# Processing sample 1011 / 1050
# Processing sample 1012 / 1050
# Processing sample 1013 / 1050
# Processing sample 1014 / 1050
# Processing sample 1015 / 1050
# Processing sample 1016 / 1050
# Processing sample 1017 / 1050
# Processing sample 1018 / 1050
# Processing sample 1019 / 1050
# Processing sample 1020 / 1050
# Processing sample 1021 / 1050
# Processing sample 1022 / 1050
# Processing sample 1023 / 1050
# Processing sample 1024 / 1050
# Processing sample 1025 / 1050
# Processing sample 1026 / 1050
# Processing sample 1027 / 1050
# Processing sample 1028 / 1050
# Processing sample 1029 / 1050
# Processing sample 1030 / 1050
# Processing sample 1031 / 1050
# Processing sample 1032 / 1050
# Processing sample 1033 / 1050
# Processing sample 1034 / 1050
# Processing sample 1035 / 1050
# Processing sample 1036 / 1050
# Processing sample 1037 / 1050
# Processing sample 1038 / 1050
# Processing sample 1039 / 1050
# Processing sample 1040 / 1050
# Processing sample 1041 / 1050
# Processing sample 1042 / 1050
# Processing sample 1043 / 1050
# Processing sample 1044 / 1050
# Processing sample 1045 / 1050
# Processing sample 1046 / 1050
# Processing sample 1047 / 1050
# Processing sample 1048 / 1050
# Processing sample 1049 / 1050

# %% [markdown]
# Helper functions for the model

# %%
# Make sure the input is always a list
def normalize_aux_feature_sets(sets):
    if sets is None: return []
    if isinstance(sets, str): return [sets]
    return list(sets)


# Defines the auxiliary features your model expects
PRECOMPUTED_AUX_FEATURE_SPECS = {
    "rms_stats": (("rms_mean", "rms_energy_mean"), ("rms_std", "rms_energy_std")),
    "spectral_flatness": (("spectral_flatness_mean", "spectral_flatness_mean"), ("spectral_flatness_std", "spectral_flatness_std")),
}

# CNN feature extractor
class MelSpectrogramEncoder(nn.Module):
    def __init__(self, dropout=0.3):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(16, 32, kernel_size=3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1), nn.ReLU(),
            nn.AdaptiveAvgPool2d((2, 2)),
        )
        self.projection = nn.Sequential(
            nn.Flatten(), nn.LazyLinear(48), nn.ReLU(), nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.projection(self.features(x))

class HybridMelSpectrogramCNN(nn.Module):
    def __init__(self, num_classes, aux_feature_dim, dropout=0.3):
        super().__init__()
        self.encoder = MelSpectrogramEncoder(dropout=dropout)
        self.classifier = nn.Sequential(
            nn.Linear(48 + aux_feature_dim, 48), nn.ReLU(),
            nn.Dropout(dropout), nn.Linear(48, num_classes),
        )

    def forward(self, x, aux_features=None):
        if aux_features is None: raise ValueError("HybridMelSpectrogramCNN requires aux_features.")
        embedding = self.encoder(x)
        combined = torch.cat([embedding, aux_features], dim=1)
        return self.classifier(combined)

# Combines: CNN embeddingh and crafted auxiliary features into one classifier.
class MelSpectrogramDataset(Dataset):
    def __init__(self, dataframe, audio_col="new_file_path", label_col="label", sample_rate=22050, 
                 fixed_duration=3.0, n_mels=128, n_fft=1024, hop_length=256, power=2.0, 
                 normalize="per_sample", aux_feature_sets=("rms_stats", "spectral_flatness")):
        self.dataframe = dataframe.reset_index(drop=True)
        self.audio_col, self.label_col = audio_col, label_col
        self.sample_rate, self.num_samples = sample_rate, int(sample_rate * fixed_duration)
        self.n_mels, self.n_fft, self.hop_length, self.power = n_mels, n_fft, hop_length, power
        self.normalize = normalize
        self.aux_feature_sets = normalize_aux_feature_sets(aux_feature_sets)

    def __len__(self): return len(self.dataframe)

    def _normalize_mel(self, mel_db):
        if self.normalize == "per_sample":
            return (mel_db - np.mean(mel_db)) / (np.std(mel_db) + 1e-8)
        return mel_db

    def __getitem__(self, index):
        row = self.dataframe.iloc[index]

        # Audio loading
        y, _ = librosa.load(row[self.audio_col], sr=self.sample_rate, mono=True)
        y = np.pad(y, (0, max(0, self.num_samples - len(y))))[:self.num_samples]

        # Mel Spec
        mel = librosa.feature.melspectrogram(y=y, sr=self.sample_rate, n_fft=self.n_fft, 
                                            hop_length=self.hop_length, n_mels=self.n_mels, power=self.power)
        mel_db = self._normalize_mel(librosa.power_to_db(mel, ref=np.max))

        # Aux Features
        feature_values = []
        for fset in self.aux_feature_sets:
            for _, source_col in PRECOMPUTED_AUX_FEATURE_SPECS[fset]:
                feature_values.append(float(row[source_col]))

        return (torch.from_numpy(mel_db).unsqueeze(0).float(), 
                torch.tensor(feature_values).float(), 
                torch.tensor(int(row[self.label_col]), dtype=torch.long))

# Evalueation function
def evaluate_and_plot(model, loader, class_names):
    """
    Generates a compact, screen-friendly confusion matrix for academic reporting.
    """
    all_preds, all_true = [], []
    model.eval()

    with torch.no_grad():
        for mels, aux, labels in loader:
            outputs = model(mels, aux)
            all_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
            all_true.extend(labels.cpu().numpy())

    # 1. Console Output
    print("\nClassification Report:\n", classification_report(all_true, all_preds, target_names=class_names))

    # 2. Figure Configuration - Reduced size for screen fit
    sns.set_theme(style="white", font_scale=0.9) 
    fig, ax = plt.subplots(figsize=(8, 6), dpi=150)

    # Calculate Accuracy Matrix
    cm = confusion_matrix(all_true, all_preds)
    cm_accuracy = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    # 3. Neutral Heatmap
    sns.heatmap(
        cm_accuracy, 
        annot=True, 
        fmt=".1%", 
        cmap="Blues", 
        xticklabels=class_names, 
        yticklabels=class_names,
        cbar_kws={'label': 'Accuracy'},
        linewidths=.5, 
        linecolor='lightgray',
        ax=ax
    )

    # 4. Formal Labeling
    ax.set_title("Hybrid CNN: Audio Effect Classification", 
                 fontsize=12, fontweight='bold', pad=15)
    ax.set_xlabel("Predicted Effect Label", fontsize=10)
    ax.set_ylabel("True Effect Label", fontsize=10)

    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Run the model using the dataset

# %%
df = feature_df.copy()
le = LabelEncoder()
df['label'] = le.fit_transform(df['effect_applied'])
test_df = df[df['split'] == 'test']

# Initialization
model = HybridMelSpectrogramCNN(num_classes=len(le.classes_), aux_feature_dim=4)
# Trigger LazyLinear with exact shapes
model(torch.randn(1, 1, 128, 258), torch.randn(1, 4)) 

try:
    model.load_state_dict(torch.load("best_hybrid_cnn.pth", map_location="cpu"))
    print("Success: Weights loaded correctly.")

    test_loader = DataLoader(MelSpectrogramDataset(test_df), batch_size=32, shuffle=False)
    evaluate_and_plot(model, test_loader, le.classes_)
except Exception as e:
    print(f"Error: {e}")
# Out:
# C:\conda_envs\assignment_2\Lib\site-packages\torch\nn\modules\lazy.py:181: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Success: Weights loaded correctly.
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       chorus       0.81      0.92      0.86       210
#        delay       0.82      0.82      0.82       210
#   distortion       0.84      0.68      0.75       210
#          dry       0.66      0.67      0.67       210
#       reverb       0.94      0.97      0.96       210
#
#     accuracy                           0.81      1050
#    macro avg       0.81      0.81      0.81      1050
# weighted avg       0.81      0.81      0.81      1050
